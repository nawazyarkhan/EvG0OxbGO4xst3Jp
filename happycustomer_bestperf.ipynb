# %% [markdown]
# ## happy customer dataset:
#
# ### Data Description:
#
# - Y = target attribute (Y) with values indicating 0 (unhappy) and 1 (happy) customers
# -  X1 = my order was delivered on time.
# -  X2 = contents of my order was as I expected
# -  X3 = I ordered everything I wanted to order
# -  X4 = I paid a good price for my order
# -  X5 = I am satisfied with my courier
# -  X6 = the app makes ordering easy for me

# %%
#adding libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
customer_df = pd.read_csv('ACME-HappinessSurvey2020.csv')

# %%
customer_df.head()
# Out:
#    Y  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %%
#Exploratory Data Analysis
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       126 non-null    int64
#  1   X1      126 non-null    int64
#  2   X2      126 non-null    int64
#  3   X3      126 non-null    int64
#  4   X4      126 non-null    int64
#  5   X5      126 non-null    int64
#  6   X6      126 non-null    int64
# dtypes: int64(7)
# memory usage: 7.0 KB

# %%
customer_df.describe()
# Out:
#                 Y          X1          X2          X3          X4          X5  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean     0.547619    4.333333    2.531746    3.309524    3.746032    3.650794
# std      0.499714    0.800000    1.114892    1.023440    0.875776    1.147641
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    4.000000    2.000000    3.000000    3.000000    3.000000
# 50%      1.000000    5.000000    3.000000    3.000000    4.000000    4.000000
# 75%      1.000000    5.000000    3.000000    4.000000    4.000000    4.000000
# max      1.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#                X6
# count  126.000000
# mean     4.253968
# std      0.809311
# min      1.000000
# 25%      4.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
features = ['X1','X2','X3','X4','X5','X6']
for feature in features:
     print(f'mean of {feature}:')
     print(customer_df[feature].mean())
     print(f"median of {feature}:")
     print(customer_df[feature].median())
     print(f"mode of {feature}:")
     print(customer_df[feature].mode()[0])
     print("#################################")
     print('\n')
# Out:
# mean of X1:
# 4.333333333333333
# median of X1:
# 5.0
# mode of X1:
# 5
# #################################
#
#
# mean of X2:
# 2.5317460317460316
# median of X2:
# 3.0
# mode of X2:
# 3
# #################################
#
#
# mean of X3:
# 3.3095238095238093
# median of X3:
# 3.0
# mode of X3:
# 3
# #################################
#
#
# mean of X4:
# 3.746031746031746
# median of X4:
# 4.0
# mode of X4:
# 4
# #################################
#
#
# mean of X5:
# 3.6507936507936507
# median of X5:
# 4.0
# mode of X5:
# 4
# #################################
#
#
# mean of X6:
# 4.253968253968254
# median of X6:
# 4.0
# mode of X6:
# 5
# #################################

# %%
customer_df.isnull().sum()
# Out:
# Y     0
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# dtype: int64

# %% [markdown]
# ### No null values in dataset

# %%
happy_customers_count=customer_df['Y'][customer_df['Y'] == 1].count()
print("Happy customers count:\n", happy_customers_count)
# Out:
# Happy customers count:
#  69

# %%
unhappy_customers_count=customer_df['Y'][customer_df['Y'] == 0].count()
print("Unhappy customers count:\n", unhappy_customers_count)
# Out:
# Unhappy customers count:
#  57

# %%
# data distribution of variable X1, X2, X3, X4, X5, X6 based on target variable Y
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Y', y=feature, data=customer_df)
    plt.title(f'Distribution of {feature} by Customer Happiness')
    plt.xlabel('Happiness (1=Happy, 0=Unhappy)')
    plt.ylabel(feature)
    plt.show()

# %%
happy_customers = customer_df[customer_df['Y'] == 1]
unhappy_customers = customer_df[customer_df['Y'] == 0]

# %%
happy_customers
# Out:
#      Y  X1  X2  X3  X4  X5  X6
# 2    1   5   3   3   3   3   5
# 5    1   5   5   3   5   5   5
# 7    1   5   4   4   4   4   5
# 12   1   5   2   4   5   5   5
# 15   1   3   2   4   3   4   4
# ..  ..  ..  ..  ..  ..  ..  ..
# 118  1   4   3   3   4   4   4
# 119  1   5   5   1   1   5   1
# 121  1   5   2   3   4   4   3
# 122  1   5   2   3   4   2   5
# 123  1   5   3   3   4   4   5
#
# [69 rows x 7 columns]

# %%
sns.countplot(x='Y', data=customer_df)
plt.title('Customer Happiness Distribution')
plt.xlabel('Happiness (1=Happy, 0=Unhappy)')
plt.ylabel('Number of Customers')
plt.show()

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       126 non-null    int64
#  1   X1      126 non-null    int64
#  2   X2      126 non-null    int64
#  3   X3      126 non-null    int64
#  4   X4      126 non-null    int64
#  5   X5      126 non-null    int64
#  6   X6      126 non-null    int64
# dtypes: int64(7)
# memory usage: 7.0 KB

# %%
#correlation matrix
correlation_matrix = customer_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Some observations about full dataset:
# - X1 & X5 are closely related.
# - X1 & X6 seems closely related too.
# - X3 & X5 seems closely related too.

# %%
#correlation matrix
correlation_matrix_happy = happy_customers.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_happy, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix_happy_customers')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix_happy_customers')

# %% [markdown]
# Some observations about happy customers (Y=1):
# - X1 & X5 are closely related.
# - X3 & X5 seems closely related too.
# - X3 & X6 seems closely related too.
# - X4 & X6 seems closely related too.

# %%
#correlation matrix
correlation_matrix_unhappy = unhappy_customers.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_unhappy, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix_unhappy_customers')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix_unhappy_customers')

# %% [markdown]
# Some observations about happy customers (Y=0):
# - X1 & X6 are very closely related.
# - X3 & X5 seems closely related too.
# - X5 & X6 seems closely related too.

# %%
# Visualize distribution 
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.histplot(customer_df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    #plt.xlabel('Happiness (1=Happy, 0=Unhappy)')
    #plt.ylabel(feature)
    plt.show()

# %%
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    print(f'Unique values for {feature}:')
    print(customer_df[feature].unique())
    print('\n')
# Out:
# Unique values for X1:
# [3 5 4 1]
#
#
# Unique values for X2:
# [3 2 4 5 1]
#
#
# Unique values for X3:
# [3 2 4 5 1]
#
#
# Unique values for X4:
# [4 5 3 2 1]
#
#
# Unique values for X5:
# [2 4 3 5 1]
#
#
# Unique values for X6:
# [4 3 5 2 1]

# %%
# finding outliers in features
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=customer_df[feature])
    plt.title(f'Boxplot of {feature} to Identify Outliers')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# - Symmetrical distribution: The mean, median, and mode are approximately equal.
# - Positively skewed (right-skewed): The mean > median > mode. The mean is pulled to the right by the extreme high values in the tail.
# - Negatively skewed (left-skewed): The mean < median < mode. The mean is pulled to the left by the extreme low values in the tail.

# %%
# function to detect outliers using IQR method
def detect_outliers_iqr(data, feature):
    feature_series = pd.Series(data[feature])
    
    # Compute IQR
    Q1 = feature_series.quantile(0.25)
    Q3 = feature_series.quantile(0.75)
    IQR = Q3 - Q1
    
    # Outlier condition
    outliers = feature_series[(feature_series < (Q1 - 1.5 * IQR)) | (feature_series > (Q3 + 1.5 * IQR))]
    return outliers.values

# %%
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    print(f'Outliers in {feature}:', detect_outliers_iqr(customer_df, feature))
# Out:
# Outliers in X1: [1]
# Outliers in X2: [5 5 5 5 5 5]
# Outliers in X3: [1 1 1 1 1 1 1]
# Outliers in X4: [1 1]
# Outliers in X5: [1 1 1 1 1 1 1]
# Outliers in X6: [2 1]

# %%
features = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in features:
    print(f'number of unique values of {feature}:')
    print(customer_df[feature].value_counts())
    print('\n')
# Out:
# number of unique values of X1:
# X1
# 5    65
# 4    40
# 3    20
# 1     1
# Name: count, dtype: int64
#
#
# number of unique values of X2:
# X2
# 3    42
# 2    34
# 1    27
# 4    17
# 5     6
# Name: count, dtype: int64
#
#
# number of unique values of X3:
# X3
# 3    55
# 4    33
# 5    17
# 2    14
# 1     7
# Name: count, dtype: int64
#
#
# number of unique values of X4:
# X4
# 4    53
# 3    41
# 5    25
# 2     5
# 1     2
# Name: count, dtype: int64
#
#
# number of unique values of X5:
# X5
# 4    50
# 5    31
# 3    22
# 2    16
# 1     7
# Name: count, dtype: int64
#
#
# number of unique values of X6:
# X6
# 5    57
# 4    47
# 3    20
# 2     1
# 1     1
# Name: count, dtype: int64

# %%
# duplicate rows
duplicate_rows = customer_df[customer_df.duplicated()]
print(f'Number of duplicate rows: {duplicate_rows.shape[0]}')
# Out:
# Number of duplicate rows: 16

# %%
customer_df_input = customer_df.drop(columns=['Y'])
customer_df_output = customer_df['Y']

# %% [markdown]
# - Value close to 0 (e.g., between -0.5 and 0.5): The distribution is approximately symmetrical.
# - positive skew (\(>0.5\)): The distribution has a long tail to the right. The bulk of the data is on the left, with the mean being greater than the median.
# - Negative skew (\(<-0.5\)): The distribution has a long tail to the left. The bulk of the data is on the right, with the mean being less than the median.
# - High skew (\(<-1\) or \(>1\)): Indicates a highly skewed distribution.

# %%
feature_name = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6']
for feature in feature_name:
    skewness_value = customer_df[feature].skew()
    print(f"Skewness of {feature}: {skewness_value}")
    if skewness_value > 1:
        print(f"The distribution of {feature} is highly positively skewed.")
    elif skewness_value < -1:
        print(f"The distribution of {feature} is highly negatively skewed.")
    elif 0.5 < skewness_value <= 1:
        print(f"The distribution of {feature} is moderately positively skewed.")
    elif -1 <= skewness_value < -0.5:
        print(f"The distribution of {feature} is moderately negatively skewed.")
    else:
        print(f"The distribution of {feature} is approximately symmetrical.")
# Out:
# Skewness of X1: -1.0584677419354833
# The distribution of X1 is highly negatively skewed.
# Skewness of X2: 0.270999638359618
# The distribution of X2 is approximately symmetrical.
# Skewness of X3: -0.19953604195426672
# The distribution of X3 is approximately symmetrical.
# Skewness of X4: -0.42223960472556293
# The distribution of X4 is approximately symmetrical.
# Skewness of X5: -0.6999992813112076
# The distribution of X5 is moderately negatively skewed.
# Skewness of X6: -0.9575897324514261
# The distribution of X6 is moderately negatively skewed.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
X,y = customer_df_input, customer_df_output
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Train model
model_rf = RandomForestClassifier()
model_rf.fit(X, y)

# Get feature importance
importances = pd.Series(model_rf.feature_importances_, index=X.columns)
importances.sort_values(ascending=True, inplace=True)

# Show least important
print("Least important features:\n", importances.head())

importances.plot(kind='barh', title='Feature Importance (Lowest to Highest)')
# Out:
# Least important features:
#  X6    0.131360
# X4    0.160519
# X1    0.167271
# X5    0.175741
# X2    0.178094
# dtype: float64
# <Axes: title={'center': 'Feature Importance (Lowest to Highest)'}>

# %%
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model_rf.score(X_train, y_train)
# Out:
# 0.94

# %%
model_rf.score(X_test, y_test)
# Out:
# 0.6538461538461539

# %%
X.skew()
# Out:
# X1   -1.058468
# X2    0.271000
# X3   -0.199536
# X4   -0.422240
# X5   -0.699999
# X6   -0.957590
# dtype: float64

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix

pipe = Pipeline([
    ('transform', PowerTransformer(method='yeo-johnson')),
    ('scale', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000))
])

pipe.fit(X_train, y_train)
print("Accuracy:", pipe.score(X_test, y_test))
print("F1 score:", f1_score(y_test, pipe.predict(X_test)))
# Out:
# Accuracy: 0.5
# F1 score: 0.5185185185185185

# %%
#removing the least imortant feature X6
X,y = customer_df_input[['X1','X2','X3','X4','X5']], customer_df_output

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model_rf.score(X_train, y_train)
# Out:
# 0.9

# %%
model_rf.score(X_test, y_test)
# Out:
# 0.7307692307692307

# %%
print("f1_score:", f1_score(y_test, model_rf.predict(X_test)))
print("Accuracy:", accuracy_score(y_test, model_rf.predict(X_test)))
print(confusion_matrix(y_test, model_rf.predict(X_test)))
# Out:
# f1_score: 0.72
# Accuracy: 0.7307692307692307
# [[10  5]
#  [ 2  9]]

# %%
X,y = customer_df_input, customer_df_output

# %%
import xgboost as xgb
model_xgb = xgb.XGBClassifier()
model_xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model_xgb.score(X_train, y_train)
# Out:
# 0.9
